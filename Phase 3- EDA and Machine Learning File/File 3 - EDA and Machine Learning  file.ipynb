# %% [markdown]
# # <span style="color:red">Project- Rental House

# %% [markdown]
# ![vector-of-a-young-family-looking-for-a-new-house-to-rent-or-buy-2DCNRNX.jpg](attachment:vector-of-a-young-family-looking-for-a-new-house-to-rent-or-buy-2DCNRNX.jpg)

# %% [markdown]
# # <span style='background :orchid' >--------------------------------------------Documentation-----------------------------------------------</span>

# %% [markdown]
#  ### <span style="color:green">Dataset Overview
#
#  Name  - table1
#  Format- csv
#  Size  - Rows-5496 and Columns-6
#
#  Name  - table2
#  Format- csv
#  Size  - Rows-5496 and Columns-5
#
#  Name  - table3
#  Format- csv
#  Size  - Rows-5496 and Columns-4
#
#  ### <span style="color:green">Variables of 'table1':
#  ['s.no',' address', 'cityname', 'state' ,'country','price(in rupees)']
#
#  ### <span style="color:green">Variables of 'table2':
#  ['s.no','bedrooms','bathrooms', 'area(sq.ft)','pets_allowed']
#
#  ### <span style="color:green">Variables of 'table3':
#  ['s.no','latitude','longitude', 'amenities']
#
#  ### <span style="color:green">Data Cleaning and Preprocessing
#
#  Prior to analysis, the dataset underwent cleaning and preprocessing steps like:
#  - Merging both dataframe(df1,df2,df3) to create One dataframe(df) having size (5496, 13).
#  - Exploratory Data Analysis (EDA)
#  - Handling Missing/Null values.
#  - Checking numbers of unique values in each column.
#  - Checking Dublicate Values & Drop dublicate values.
#  - Dropping Irrelevant columns
#  - Seperating Numerical and Categorical column
#
#  - Data Visualization:
#     Univariate Analysis
#     Bivariate Analysis
#     Multivariate Analysis
#     Outliers Analysis
#  - Checking and Removing Skewness .
#  - Checking and Removing Outliers by Z-score & Inter Quantile Range .
#  - Fill the Nan Values by Knn Imputers.
#
# ### <span style="color:green">Training:
#
#  - Training Process:
#     - Encoding Categorical Variable (By Using LabelEncoder)
#     - Feature Selection by Visualizing Correlation by using heatmap.
#     - Seperating Feature and Label for Model 1 'Price(in rupees)' and Model 2 'area(sq.ft)'.
#     - Feature Scaling Using Standard Scaler for both model
#     - Checking Multicollinearity by using VIF method.
#     - Feature Selection by SelectKBest for 'Price(in rupees)'(9 Column remaining)
#     - Feature Selection by SelectKBest for 'area(sq.ft)'(8 Column remaining)
#     - Train on different different model
#
#  -Training Data:
#     Model 1 ('Price(in rupees)'): Rows & Column (3666, 9))
#     Model 2 ('area(sq.ft)': Rows & Column (3666, 8)
#
# ### <span style="color:green">Evaluation
#
#  - Metrics for Predicting Model 1 ('Price(in rupees)'):
#     - Use R^2 score, Mean Absolute Error, Cross-Validation score
#     - Mean Squared Error, Root Mean Squared Error
#     used to evaluate the performance of the model.
#
#  - Metrics for Predicting Model 2 ('area(sq.ft)') :
#     - Use R^2 score, Mean Absolute Error, Cross-Validation score
#     - Mean Squared Error, Root Mean Squared Error
#     used to evaluate the performance of the model.
#
# ### <span style="color:green">Model Performance :
#    Model 1 ('Price(in rupees)'):
#    Out of all model,RandomForestRegressor perform best for this dataset.
#    - Accuracy Before Hyperparameter Tunning :
#       - R^2 Score of RandomForestRegressor = 70.94%
#    - Accuracy After Hyperparameter Tunning:
#       - R^2 Score of RandomForestRegressor = 71.34% (slightly increase)
#  Hence i considered RandomForestRegressor as our final model for prediction of 'Price(in rupees)' with least Mean Absolute Error.
#
#    Model 2 ('area(sq.ft)'):
#    Out of all model,RandomForestRegressor & Support Vector Regression perform best for this dataset.
#    - Accuracy Before Hyperparameter Tunning :
#       - R^2 Score of RandomForestRegressor = 77.59%
#       - R^2 Score of Support Vector Regression = 74.96%
#    - Accuracy After Hyperparameter Tunning:
#       - R^2 Score of RandomForestRegressor = 78.30% (slightly increase)
#       - R^2 Score of Support Vector Regression (SVR) = 74.96% (remain same)
#  Hence i considered RandomForestRegressor as our final model for prediction of 'area(sq.ft)' with least Mean Absolute Error.
#
# ### <span style="color:green">Conclusion:
#
# Model 1  (Predicting 'Price(in rupees)'):
# This case study dataset provides for prediction of  price for rental data which is continious data.
# It is clearly a Regression problem where "Price(in rupees)" is target column and remaining columns are features.
# RandomForestRegressor perform well with R^2 Score 71.34 % with less mean absolute error.The model shows no sign of Underfitting or Overfitting. This means the model generalizing well for unseen data.
#
# Model 1  (Predicting 'area(sq.ft)')
# This case study dataset provides for prediction of area(sq.ft) for rental house which is continious data.
# It is clearly a Regression problem where "area(sq.ft)" is target column and remaining columns are features.
# RandomForestRegressor perform well with R^2 Score 78.30 % with less mean absolute error.The model shows no sign of Underfitting or Overfitting. This means the model generalizing well for unseen data.

# %% [markdown]
# # <span style='background :orchid' >----------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ## <span style="color:red">PYTHON IMPLEMENTATION

# %%
#Import Necessary Libraries

#Data Visualization
import pandas as pd
import numpy as np

#Data Visualization 
import seaborn as sns
import matplotlib.pyplot as plt

#Ignore Unnecessary warning
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing Dataset

df1=pd.read_csv(r"C:\Users\nirma\table1.csv")
df2=pd.read_csv(r"C:\Users\nirma\table2.csv")
df3=pd.read_csv(r"C:\Users\nirma\table3.csv")

# %%
# List of DataFrames to concatenate
dfs = [df1, df2, df3]

# Use pd.concat to concatenate DataFrames along rows
df = pd.concat(dfs, ignore_index=False)

# %%
df
# Out:
#         s.no amenities  bathrooms  bedrooms pets_allowed  area(sq.ft)  \
# 0        1.0       NaN        NaN       0.0         None        101.0
# 1        2.0       NaN        NaN       1.0         None        106.0
# 2        3.0       NaN        1.0       0.0         None        107.0
# 3        4.0       NaN        1.0       0.0         None        116.0
# 4        5.0       NaN        NaN       0.0         None        125.0
# ...      ...       ...        ...       ...          ...          ...
# 5492  5493.0       NaN        4.0       6.0         None       5921.0
# 5493  5494.0       NaN        4.0       5.0         None       6300.0
# 5494  5495.0       NaN        8.0       6.0         None       8716.0
# 5495  5496.0       NaN        8.5       6.0         None      11318.0
# 5496     NaN       NaN        NaN       NaN          NaN          NaN
#
#                         address      cityname state  latitude  longitude  \
# ...

# %%
#dropping last record
last_row_index = df.index[-1]
df = df.drop(last_row_index)

# reset the index after removing the row
df = df.reset_index(drop=True)

# %%
df
# Out:
#         s.no amenities  bathrooms  bedrooms pets_allowed  area(sq.ft)  \
# 0        1.0       NaN        NaN       0.0         None        101.0
# 1        2.0       NaN        NaN       1.0         None        106.0
# 2        3.0       NaN        1.0       0.0         None        107.0
# 3        4.0       NaN        1.0       0.0         None        116.0
# 4        5.0       NaN        NaN       0.0         None        125.0
# ...      ...       ...        ...       ...          ...          ...
# 5491  5492.0       NaN        5.0       4.0         None       5407.0
# 5492  5493.0       NaN        4.0       6.0         None       5921.0
# 5493  5494.0       NaN        4.0       5.0         None       6300.0
# 5494  5495.0       NaN        8.0       6.0         None       8716.0
# 5495  5496.0       NaN        8.5       6.0         None      11318.0
#
#                         address      cityname state  latitude  longitude  \
# ...

# %% [markdown]
# ## <span style="color:purple">Exploratory Data Analysis (EDA)

# %%
print(f'The Number of Rows and Columns in Dataset is :{df.shape}')
print( f'\n Columns Name are :{df.columns}')
# Out:
# The Number of Rows and Columns in Dataset is :(5496, 13)
#
#  Columns Name are :Index(['s.no', 'amenities', 'bathrooms', 'bedrooms', 'pets_allowed',
#        'area(sq.ft)', 'address', 'cityname', 'state', 'latitude', 'longitude',
#        'country', 'price(in rupees)'],
#       dtype='object')

# %%
#Getting Information Of Dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5496 entries, 0 to 5495
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   s.no              5496 non-null   float64
#  1   amenities         1947 non-null   object
#  2   bathrooms         5465 non-null   float64
#  3   bedrooms          5492 non-null   float64
#  4   pets_allowed      4900 non-null   object
#  5   area(sq.ft)       5496 non-null   float64
#  6   address           4418 non-null   object
#  7   cityname          5442 non-null   object
#  8   state             5442 non-null   object
#  9   latitude          5489 non-null   float64
#  10  longitude         5489 non-null   float64
#  11  country           5495 non-null   object
#  12  price(in rupees)  5496 non-null   float64
# dtypes: float64(7), object(6)
# memory usage: 558.3+ KB

# %% [markdown]
# <span style="color:BLUE">Observation -
# - There are two data types present in dataset:(object,float64).
# - Some Column has null values.

# %%
#setting Date as Dataframe Object 
df.set_index('s.no',inplace =True)

# %%
#Cheking Duplicate values
df.duplicated().sum()
# Out:
# 30

# %% [markdown]
# <span style="color:BLUE">Observation -
# - There are 30 dublicate rows present in dataset. Let's delete it.

# %%
#Removing dublicates data
df= df.drop_duplicates()
df = df.reset_index(drop=True)

# %%
#Checking numbers of unique values in each column
df.nunique().to_frame("No. of Unique Value")
# Out:
#                   No. of Unique Value
# amenities                          37
# bathrooms                          14
# bedrooms                           10
# pets_allowed                        4
# area(sq.ft)                      1546
# address                          4411
# cityname                         1193
# state                              51
# latitude                         1563
# longitude                        1563
# country                             1
# price(in rupees)                 1175

# %%
#Checking the ValueCount(i.e frequency of each value) of each Column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Parking                                                                                                231
# Dishwasher,Refrigerator                                                                                223
# Dishwasher,Parking,Pool                                                                                149
# Dishwasher                                                                                             149
# Dishwasher,Parking,Refrigerator                                                                         93
# Parking,Pool                                                                                            92
# Refrigerator                                                                                            85
# Parking,Refrigerator                                                                                    65
# Parking,Storage                                                                                         64
# ...

# %%
#Replace 'None' to 'No' in  pets_allowed Column  
df['pets_allowed']=df['pets_allowed'].replace('None','No')

# %%
#Replace 'Cats,Dogs',''Cats','Dogs' to 'Yes' in  pets_allowed Column  
df['pets_allowed']=df['pets_allowed'].replace({'Cats,Dogs':'Yes', 'Cats':'Yes','Dogs':'Yes'})

# %%
#Count the value
df['pets_allowed'].value_counts()
# Out:
# Yes    3065
# No     1834
# Name: pets_allowed, dtype: int64

# %%
#Dropping Country Column as it has only one unique value
df.drop(['country'], axis=1 ,inplace =True )
df.shape
# Out:
# (5466, 11)

# %%
#checking the null values in each column
df.isnull().sum()
# Out:
# amenities           3542
# bathrooms             31
# bedrooms               4
# pets_allowed         567
# area(sq.ft)            0
# address             1048
# cityname              54
# state                 54
# latitude               7
# longitude              7
# price(in rupees)       0
# dtype: int64

# %% [markdown]
# <span style="color:BLUE">Observation -
# - There are columns having null values present in dataset. Fill that nan values after visualization.

# %%
#Statical summary of numerical feature
df.describe()
# Out:
#          bathrooms     bedrooms   area(sq.ft)     latitude    longitude  \
# count  5435.000000  5462.000000   5466.000000  5459.000000  5459.000000
# mean      1.456670     1.874039   1019.385657    37.536301   -96.887773
# std       0.697747     1.053185    630.886775     5.779549    15.884928
# min       1.000000     0.000000    101.000000    21.315500  -158.022100
# 25%       1.000000     1.000000    648.000000    33.193200  -105.111900
# 50%       1.000000     2.000000    845.000000    37.815200   -96.040400
# 75%       2.000000     2.000000   1202.750000    41.471200   -84.392200
# max       8.500000     9.000000  11318.000000    61.594000   -70.370600
#
#        price(in rupees)
# count      5.466000e+03
# mean       1.310849e+05
# std        9.021047e+04
# min        1.662400e+04
# 25%        7.938000e+04
# 50%        1.101340e+05
# 75%        1.492000e+05
# max        2.078000e+06

# %% [markdown]
# <span style="color:blue">Observation -From the above description , we can observe the following things:
# - Missing values are present in all numerical column .
# - Data Distribution is Right Skewed in 'bathrooms', 'area(sq.ft)' and 'price(in rupees)' column(The mean value is greater than median(50%)).
# - There is difference in 75% and max value in few columns ,it means Outliers are present in the dataset.

# %%
#Seperating Numerical and Categorical column

#checking for Categorical column
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical_column",categorical_col)
print("\n")

#checking for Numerical column
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical_column",numerical_col)
# Out:
# Categorical_column ['amenities', 'pets_allowed', 'address', 'cityname', 'state']
#
#
# Numerical_column ['bathrooms', 'bedrooms', 'area(sq.ft)', 'latitude', 'longitude', 'price(in rupees)']

# %% [markdown]
# ##  <span style="color:purple">Data Visualization

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# ##  <span style="color:red">Model 1- Predicting 'price(in rupees)'

# %%
#Visualize "price(in rupees)" i.e Target variable for 1st Model
plt.figure(figsize = (15,5),facecolor = 'lightskyblue')
sns.histplot(x="price(in rupees)",data=df,color='g',kde=True)
plt.xlabel('price(in rupees)',fontsize=20)
# Out:
# Text(0.5, 0, 'price(in rupees)')

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Data distribution in 'price(in rupees)' is right skewed.

# %% [markdown]
# ##  <span style="color:red">Model 2- Predicting 'area(sq.ft)'

# %%
#Visualize "area(sq.ft)" i.e Target variable for 2nd Model
plt.figure(figsize = (15,5),facecolor = 'lightskyblue')
sns.histplot(x="area(sq.ft)",data=df,color='r',kde=True)
plt.xlabel('area(sq.ft)',fontsize=20)
# Out:
# Text(0.5, 0, 'area(sq.ft)')

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Data distribution in 'area(sq.ft)' is right skewed.

# %%
#Visualize "bathrooms" 
plt.figure(figsize = (15,5),facecolor = 'lightskyblue')
sns.histplot(x="bathrooms",data=df,color='b')
plt.xlabel('No. of bathrooms',fontsize=20)
plt.ylabel('Count',fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Most rental house  has 1 & 2 bathrooms.

# %%
#Visualize "bedrooms" 
plt.figure(figsize = (15,5),facecolor = 'lightskyblue')
sns.histplot(x="bedrooms",data=df,color='r')
plt.ylabel('Count',fontsize=15)
plt.xlabel('No. of bedrooms',fontsize=20)
# Out:
# Text(0.5, 0, 'No. of bedrooms')

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Most rental house  has 1 & 2 bedrooms.

# %%
#Visualize "latitude" 
plt.figure(figsize = (15,5),facecolor = 'lightskyblue')
sns.histplot(x="latitude",data=df,color='g',kde=True)
plt.ylabel('Count',fontsize=20)
plt.xlabel('Latitude',fontsize=20)
# Out:
# Text(0.5, 0, 'Latitude')

# %%
#Visualize "longitude" 
plt.figure(figsize = (15,5),facecolor = 'lightskyblue')
sns.histplot(x="longitude",data=df,color='r',kde=True)
plt.ylabel('Count',fontsize=15)
plt.xlabel('Longitude',fontsize=20)
# Out:
# Text(0.5, 0, 'Longitude')

# %%
#Visualize 'state' column 
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.countplot(x="state", data=df)
plt.xticks(fontsize=15,rotation =90)
plt.ylabel('Count',fontsize=15)
plt.yticks(fontsize=10)
plt.xlabel('Name of state',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Most rental house are present in Texax State .

# %%
#Visualize 'Has Online delivery' column
plt.figure(figsize = (5,10))
Ls= df["pets_allowed"].value_counts()
plt.pie(Ls.values, labels= Ls.index, data=df, autopct='%1.1f%%')
plt.title("pets_allowed",fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Pets are allowed in most rental house.

# %%
#Getting top 10 City Name and Visualize it
top_10_city = df['cityname'].value_counts()[:10]

plt.figure(figsize=(20,5))
sns.barplot(y=top_10_city.values, x=top_10_city.index)

plt.xticks(fontsize=15,rotation =90)
plt.xlabel('City Name',fontsize=20)
plt.ylabel('Count',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Top 10 City Name',fontsize=25)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Most rental house are present in Austin City USA.

# %%
#Getting top 10 amenities and Visualize it

plt.figure(figsize=(20,5))
sns.barplot(y= df['amenities'].value_counts()[:10].values, x= df['amenities'].value_counts()[:10].index)

plt.xticks(fontsize=15,rotation =90)
plt.xlabel('amenities',fontsize=20)
plt.ylabel('Count',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Top 10 amenities',fontsize=25)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Most rental house are having Parking , Dishwasher and Refrigrator amenities .

# %% [markdown]
# ### BIVARIATE ANALYSIS FOR MODEL 1

# %%
#Visualize "price(in rupees)" vs "bedrooms"
plt.figure(figsize=(15,5),facecolor = 'yellowgreen')
sns.stripplot(y="price(in rupees)",x="bedrooms",data=df,color='r')
plt.xlabel('No. of bedrooms', fontsize =15)
plt.ylabel('price(in rupees)', fontsize =15)
plt.title('Rental Price For Different No. of bedrooms',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Price of rental house is increasing as no. of bedrooms increases.

# %%
#Visualize "price(in rupees)" vs "bathrooms"
plt.figure(figsize=(15,5),facecolor = 'yellowgreen')
sns.stripplot(y="price(in rupees)",x="bathrooms",data=df,color='g')
plt.xlabel('No. of bathrooms', fontsize =15)
plt.ylabel('price(in rupees)', fontsize =15)
plt.title('Rental Price For Different No. of bathrooms',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Price of rental house is increasing as no.of bathrooms increases.

# %%
#Visualize "price(in rupees)" vs "area(sq.ft)"
plt.figure(figsize=(15,5),facecolor = 'yellowgreen')
sns.scatterplot(x="area(sq.ft)",y="price(in rupees)",data=df,color='b')
plt.xlabel('area(sq.ft)', fontsize =15)
plt.ylabel('price(in rupees)', fontsize =15)
plt.title('Rental Price For Different Area',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Price of rental house is increasing as area of rental house increases. Hence direct relationship.

# %%
#Visualize "price(in rupees)" vs "state"
plt.figure(figsize=(15,5),facecolor = 'yellowgreen')
sns.barplot(x="state",y="price(in rupees)",data=df)
plt.xlabel('state', fontsize =15)
plt.ylabel('price(in rupees)', fontsize =15)
plt.title('Rental Price in Different State',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Price of rental house is highest in RI and HI State.

# %%
#Visualize "price(in rupees)" vs "pets_allowed"
sns.catplot(x="pets_allowed",y="price(in rupees)",data=df,color='brown')
plt.xlabel('pets_allowed', fontsize =15)
plt.ylabel('price(in rupees)', fontsize =15)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - No relation between 'price' and 'Pet_allowed'.

# %%
#Visualize 'Rental Price in top 15 City'
plt.figure(figsize=(15,5))
sns.barplot(x='cityname',data=df, y='price(in rupees)',order=df['cityname'].value_counts().index[:15])

plt.xticks(fontsize=10,rotation =90)
plt.xlabel('City Name',fontsize=15)
plt.ylabel('price(in rupees)',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Rental Price in Top 15 City',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Price of rental house is highest in Los Angelese and San Francisco City.

# %%
#Visualize 'Rental Price in top 10 address'
plt.figure(figsize=(15,5))
sns.barplot(x='address',data=df, y='price(in rupees)',color='g',order=df['address'].value_counts().index[:15])

plt.xticks(fontsize=10,rotation =90)
plt.xlabel('Address Name',fontsize=15)
plt.ylabel('price(in rupees)',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Rental Price in Top 15 Address',fontsize=20)
plt.show()

# %%
#Visualize 'Rental Price for top 10 amenities'
plt.figure(figsize=(15,5),facecolor = 'yellowgreen')
sns.barplot(x='amenities',data=df, y='price(in rupees)',color='b',order=df['amenities'].value_counts().index[:10])

plt.xticks(fontsize=10,rotation =90)
plt.xlabel('Top 10 Amenities',fontsize=15)
plt.ylabel('price(in rupees)',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Rental Price for Top 10 Amenities',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Price of rental house is going higher when Parking ,Dishwasher and Refrigrator amenities are provided.

# %% [markdown]
# ### BIVARIATE ANALYSIS FOR MODEL 2

# %%
#Visualize "area(sq.ft)" vs "bedrooms"
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.stripplot(y="area(sq.ft)",x="bedrooms",data=df,color='r')
plt.xlabel('No. of bedrooms', fontsize =15)
plt.ylabel('Area(sq.ft)', fontsize =15)
plt.title('Area(sq.ft) W.R.T Different No. of Bedrooms',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Area of rental house is increasing as no. of bedrooms increases.

# %%
#Visualize "area(sq.ft)" vs "bathrooms"
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.stripplot(y="area(sq.ft)",x="bathrooms",data=df,color='g')
plt.xlabel('No. of bathrooms', fontsize =15)
plt.ylabel('Area(sq.ft)', fontsize =15)
plt.title('Area(sq.ft) W.R.T Different No. of Bathrooms',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Area of rental house is increasing as no. of bathrooms increases.

# %%
#Visualize 'Area(sq.ft) W.R.T To Top 10 Amenities'
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.barplot(x='amenities',data=df, y='area(sq.ft)',color='orchid',order=df['amenities'].value_counts().index[:10])

plt.xticks(fontsize=10,rotation =90)
plt.xlabel('Top 10 Amenities',fontsize=15)
plt.ylabel('Area(sq.ft)',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Area(sq.ft) W.R.T To Top 10 Amenities',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Area of rental house is highest for Dishwasher and Refrigerator aminities.

# %%
#Visualize "area(sq.ft)" vs "pets_allowed"
sns.catplot(x="pets_allowed",y="area(sq.ft)",data=df,color='g')
plt.xlabel('pets_allowed', fontsize =15)
plt.ylabel('Area(sq.ft)', fontsize =15)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Rental house having large area does not allow pets.

# %%
#Visualize 'area(sq.ft) in top 10 address'
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.barplot(x='address',data=df, y='area(sq.ft)',color='brown',order=df['address'].value_counts().index[:15])

plt.xticks(fontsize=10,rotation =90)
plt.xlabel('Address Name',fontsize=15)
plt.ylabel('Area(sq.ft)',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Area(sq.ft) in Top 15 Address',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - No Relation.

# %%
#Visualize 'Area in top 15 City'
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.barplot(x='cityname',data=df, y='area(sq.ft)',order=df['cityname'].value_counts().index[:15])

plt.xticks(fontsize=10,rotation =90)
plt.xlabel('City Name',fontsize=15)
plt.ylabel('Area(sq.ft)',fontsize=15)
plt.yticks(fontsize=10)
plt.title('Area(sq.ft) in Top 15 City',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Rental house in San Diego having large property area.

# %%
#Visualize "area(sq.ft)" vs "state"
plt.figure(figsize=(15,5),facecolor = 'lightskyblue')
sns.stripplot(y="area(sq.ft)",x="state",data=df,color='brown')
plt.xlabel('State', fontsize =15)
plt.ylabel('Area(sq.ft)', fontsize =15)
plt.title('Area(sq.ft) For Different State',fontsize=20)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Rental house in CA state has different different prperty area.

# %% [markdown]
# ### Multivariate  Analysis

# %%
# Multivariate  Analysis 
sns.pairplot( df)

# %% [markdown]
# ## <span style="color:purple">Let's Fill Nan Values By Different Method

# %%
#Number of Null Values in each column
print(df.isna().sum())
# Out:
# amenities           3542
# bathrooms             31
# bedrooms               4
# pets_allowed         567
# area(sq.ft)            0
# address             1048
# cityname              54
# state                 54
# latitude               7
# longitude              7
# price(in rupees)       0
# dtype: int64

# %%
#Fill Null Values in ('amenities') by 'Not Available'
df['amenities'] = df['amenities'].fillna('Not Available')

# %%
#Fill Null Values in ('bathrooms') by mode method
df["bathrooms"] = df["bathrooms"].fillna(df["bathrooms"].mode().iloc[0])

# %%
#KNN Imputer for impute "bedrooms" NaN value with 'area(sq.ft)'

from sklearn.impute import KNNImputer
KI=KNNImputer(n_neighbors=3)

#Creating dataframe for imputed value 
knn_imputer=pd.DataFrame(KI.fit_transform(df[["area(sq.ft)",'bedrooms']]))
#Naming the columns of Imputer DataFrame
knn_imputer.columns=["area(sq.ft)",'bedrooms']

# Update the original DataFrame with the imputed values
df["bedrooms"]=knn_imputer["bedrooms"]
df["bedrooms"]
# Out:
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
#        ...
# 5461    4.0
# 5462    6.0
# 5463    5.0
# 5464    6.0
# 5465    6.0
# Name: bedrooms, Length: 5466, dtype: float64

# %%
#Fill Null Values in ('pets_allowed', 'cityname','state') by mode method
df[['pets_allowed', 'cityname','state']]=df[['pets_allowed', 'cityname','state']].fillna(df[['pets_allowed', 'cityname','state']].mode().iloc[0])

# %%
#Fill Null Values in ('latitude', 'longitude') by median method
df[['latitude', 'longitude']]=df[['latitude', 'longitude']].fillna(df[['latitude', 'longitude']].median())

# %%
#Fill Null Values in ('address') by 'Address Not Available'
df['address'] = df['address'].fillna('Address Not Available')

# %%
#Lets check number of Null values in each column again 
print(df.isna().sum())
# Out:
# amenities           0
# bathrooms           0
# bedrooms            0
# pets_allowed        0
# area(sq.ft)         0
# address             0
# cityname            0
# state               0
# latitude            0
# longitude           0
# price(in rupees)    0
# dtype: int64

# %% [markdown]
# ## <span style="color:purple">Checking for outliers

# %%
#checking outliers by using Boxplot 
plt.figure(figsize=(20,10))
p=1
for i in numerical_col:
    if p<=6:
        plt.subplot(2,3,p)
        sns.boxplot(y=df[i], palette="viridis")
        plt.xlabel (i, fontsize =20)
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# <span style="color:purple">Observation:
# - All Numerical Features has Outliers. Lets remove Outliers .

# %% [markdown]
# ## <span style="color:purple">Removing Outliers
# Numerical Features has Outliers. Lets remove Outliers by IQR method or Z-score

# %%
#Remove Outliers by zscore

from scipy.stats import zscore
outliers_feature = df[['bathrooms', 'bedrooms', 'area(sq.ft)', 'latitude', 'longitude', 'price(in rupees)']]
z=np.abs(zscore(outliers_feature)) #.abs() to remove negative values
z.head()
# Out:
#    bathrooms  bedrooms  area(sq.ft)  latitude  longitude  price(in rupees)
# 0   0.651902  1.779989     1.455839  0.237050   1.253712          0.725258
# 1   0.651902  0.830314     1.447913  0.074687   0.581138          1.061603
# 2   0.651902  1.779989     1.446328  0.234505   1.247696          0.172367
# 3   0.651902  1.779989     1.432061  1.745242   1.602740          0.600860
# 4   0.651902  1.779989     1.417794  0.231527   1.246190          0.642323

# %%
#Z-score>3
np.where(z>3)
# Out:
# (array([  40,   40,  139,  139,  166,  166,  210,  210,  240,  240,  360,
#          360,  364,  364,  401,  401,  427,  427,  451,  451,  473,  473,
#          520,  582,  582,  659,  763,  763,  779,  779,  783,  783,  811,
#          811,  953,  953, 1038, 1048, 1048, 1065, 1065, 1154, 1154, 1273,
#         1273, 1429, 1429, 1597, 1597, 1630, 1630, 1631, 1631, 2026, 2026,
#         2043, 2500, 2500, 2564, 2793, 2793, 2824, 2870, 2878, 2964, 2981,
#         2999, 3051, 3051, 3061, 3061, 3114, 3116, 3175, 3516, 3546, 3546,
#         3580, 3584, 3731, 3916, 3960, 4028, 4029, 4052, 4124, 4133, 4220,
#         4232, 4279, 4280, 4295, 4295, 4326, 4334, 4346, 4469, 4469, 4541,
#         4554, 4554, 4601, 4644, 4719, 4745, 4866, 4878, 4881, 4882, 4894,
#         4898, 4898, 4919, 4926, 4938, 4957, 5005, 5011, 5013, 5020, 5044,
#         5048, 5066, 5066, 5072, 5090, 5144, 5145, 5148, 5157, 5157, 5157,
#         5168, 5185, 5186, 5195, 5200, 5205, 5214, 5219, 5221, 5224, 5225,
# ...

# %%
#now removing the data above zscore and creating a new dataframe
df1=df[(z<3).all(axis=1)]
print("New Dataframe having rows and column: " ,df1.shape)
print("New Dataframe column's name: " ,df1.columns)
# Out:
# New Dataframe having rows and column:  (5238, 11)
# New Dataframe column's name:  Index(['amenities', 'bathrooms', 'bedrooms', 'pets_allowed', 'area(sq.ft)',
#        'address', 'cityname', 'state', 'latitude', 'longitude',
#        'price(in rupees)'],
#       dtype='object')

# %%
print("Data Loss Percentage with Z-score method:",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage with Z-score method: 4.171240395170143

# %%
#Remove Outliers by IQR

#1st Quantile
q1=outliers_feature.quantile(0.25)

#3rd Quantile
q3=outliers_feature.quantile(0.75)

#calculating IQR
iqr=q3-q1

df2=df[~((df < (q1 - 1.5*iqr ))|(df > (q3 + 1.5*iqr ))).any(axis=1)]

# %%
print("Data Loss Percentage with Z-score method:",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage with Z-score method: 14.471276984998171

# %% [markdown]
# <span style="color:blue">Conclusion -Data Loss Percentage  with IQR method is very high as compared with Z-score . So i go with z-score.

# %%
#Storing Dataframe with Z-score method in old dataframe
df=df1

# %%
#reset the index after removing outliers values
df.reset_index( drop=True, inplace=True)
df.shape
# Out:
# (5238, 11)

# %% [markdown]
# ## <span style="color:purple">Checking Skewness

# %%
#Checking for data distribution in numerical column
plt.figure(figsize = (20,10), facecolor = 'skyblue')
plotnumber = 1 #this is an initiator

for column in numerical_col:
    if plotnumber <=6: 
        ax = plt.subplot (3,2, plotnumber)
        sns.distplot (df [column],color='green')
        plt.xlabel (column, fontsize =15)
    plotnumber +=1
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - From the above graph, Data Distribution is not normal in all column except latitude and longitude

# %% [markdown]
# ## <span style="color:purple">Removing Skewness

# %%
df.skew()
# Out:
# bathrooms           1.222772
# bedrooms            0.761710
# area(sq.ft)         1.277855
# latitude            0.073636
# longitude          -0.404225
# price(in rupees)    1.567864
# dtype: float64

# %%
#Removing Skewness for 'bathrooms' using PowerTransformer
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method="yeo-johnson")
skewed_feature=pt.fit_transform(df[['bathrooms']])
df['bathrooms']=skewed_feature
df['bathrooms'].skew()
# Out:
# 0.6510292934302155

# %%
#Removing Skewness using cuberoot again
df['bathrooms']=np.cbrt(df['bathrooms'])
df['bathrooms'].skew()
# Out:
# 0.6128339594392856

# %%
#Removing Skewness using cuberoot again
df['bathrooms']=np.cbrt(df['bathrooms'])
df['bathrooms'].skew()
# Out:
# 0.6088664264447857

# %%
#Removing Skewness for "bedrooms" using cuberoot again
df['bedrooms']=np.sqrt(df['bedrooms'])
df['bedrooms'].skew()
# Out:
# -0.48255661681076667

# %%
#Removing Skewness for 'area(sq.ft)' using cuberoot method 
df['area(sq.ft)']=np.cbrt(df['area(sq.ft)'])
df['area(sq.ft)'].skew()
# Out:
# 0.36921475012002875

# %%
#Removing Skewness for 'price(in rupees)' using cuberoot method 
df['price(in rupees)']=np.cbrt(df['price(in rupees)'])
df['price(in rupees)'].skew()
# Out:
# 0.7008767894862165

# %%
#Removing Skewness for 'price(in rupees)' using cuberoot again
df['price(in rupees)']=np.cbrt(df['price(in rupees)'])
df['price(in rupees)'].skew()
# Out:
# 0.4261202289433517

# %%
df.skew()
# Out:
# bathrooms           0.608866
# bedrooms           -0.482557
# area(sq.ft)         0.369215
# latitude            0.073636
# longitude          -0.404225
# price(in rupees)    0.426120
# dtype: float64

# %% [markdown]
# # <span style="color:purple">Encoding Categorical Column

# %%
#Encoding Column using labelEncoder
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = LE.fit_transform(df[column])
        
df.head()
# Out:
#    amenities  bathrooms  bedrooms  pets_allowed  area(sq.ft)  address  \
# 0         27   -0.96645       0.0             0     4.657010     4143
# 1         27   -0.96645       1.0             0     4.732623     3827
# 2         27   -0.96645       0.0             0     4.747459     4143
# 3         27   -0.96645       0.0             0     4.876999     1134
# 4         27   -0.96645       0.0             0     5.000000     4143
#
#    cityname  state  latitude  longitude  price(in rupees)
# 0      1082      6   38.9057   -76.9861          3.429725
# 1       317     13   37.9680   -87.6621          3.201429
# 2        34     43   38.8910   -77.0816          3.651948
# 3       948     45   47.6160  -122.3275          3.490374
# 4        34     43   38.8738   -77.1055          3.471088

# %% [markdown]
# <span style="color:BLUE">Observation -Hence we encoded categorical column sucessfully. Let's go with this value.

# %% [markdown]
# ## <span style="color:purple">Correlation between target variable and Independent variable

# %%
#checking the corelation  again using heatmaps (only absolute values)
plt.figure(figsize = (20,20))
sns.heatmap(df.corr(), annot = True, linewidths=0.5, fmt='.2f',cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Here Some Column are weakly correlated.
# - Column 'area(sq.ft)' ,'bedrooms'& 'bathrooms'are strongly correlated ,which cause Multicollinearity to occur.
#     But Lets check  Multicollinearity by VIF method later.

# %%
#Storing dataframe into another one for 2nd model
df_two=df.copy()
df_two.shape
# Out:
# (5238, 11)

# %% [markdown]
# ##  <span style="color:red">Model 1- Predicting 'price(in rupees)'

# %%
#Visualizing Correlaton using Bar Plot
plt.figure(figsize = (15,5))
df_corr = df.corr()
df_corr['price(in rupees)'].sort_values(ascending=False).drop('price(in rupees)').plot.bar()
plt.xticks(fontsize =15)
plt.xlabel('Features', fontsize =15)
plt.ylabel('Correlation_Value', fontsize =15)
plt.title('Correlaton using Bar Plot', fontsize =25)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Column 'address' has  no correlated with 'price(in rupees)'.
# Let's drop this value.

# %%
#Dropping  "address" column
df.drop(['address'],axis=1,inplace=True)
df.shape
# Out:
# (5238, 10)

# %% [markdown]
# ## <span style="color:purple">Seperating Feature and Label

# %%
#Seperating Feature and label into x and y
x=df.drop(["price(in rupees)"],axis=1)
y=df["price(in rupees)"]

print("Feature Dimension :" ,x.shape)
print("Target Dimension :" ,y.shape)
# Out:
# Feature Dimension : (5238, 9)
# Target Dimension : (5238,)

# %% [markdown]
# ## <span style="color:purple">Feature Scaling Using Standard Scaler

# %%
# data scaling 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %% [markdown]
# ## <span style="color:purple">Detecting Multicollinearity Using a Variance Inflation Factor (VIF)

# %%
#finding VIF in each scaled column i.e x_scaled.shape[1](1/1- R^2 )
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame() 

vif["VIF"] = [variance_inflation_factor(x_scaled.values, i) for i in range(len(x_scaled.columns))]
vif["Features"] = x_scaled.columns
vif
# Out:
#         VIF      Features
# 0  1.039697     amenities
# 1  2.304917     bathrooms
# 2  2.257598      bedrooms
# 3  1.058221  pets_allowed
# 4  2.949309   area(sq.ft)
# 5  1.043221      cityname
# 6  1.034841         state
# 7  1.054477      latitude
# 8  1.045755     longitude

# %% [markdown]
# <span style="color:blue">Observation - THe VIF value is below 10 in all feature ,Hence no multicollinearity observed.
# Lets go ahead with these feature.

# %% [markdown]
# ## <span style="color:purple"> Feature Selection by SelectKBest

# %%
from sklearn.feature_selection import SelectKBest, f_classif

best_fit = SelectKBest(score_func = f_classif, k =9)
fit = best_fit.fit(x_scaled,y)

#Craete DataFrame for score and column
df_scores = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(x_scaled.columns)

#Concatenate the score and column
featureScores = pd.concat([df_columns,df_scores],axis = 1)
featureScores.columns = ['Feature', 'Score']

#print the top 9 feature based on score
print(featureScores.nlargest(9,'Score'))
# Out:
#         Feature     Score
# 4   area(sq.ft)  2.327979
# 1     bathrooms  2.224380
# 8     longitude  1.763768
# 2      bedrooms  1.580949
# 6         state  1.565876
# 0     amenities  1.494496
# 7      latitude  1.290580
# 5      cityname  1.219000
# 3  pets_allowed  1.186855

# %% [markdown]
# <span style="color:blue">Obsevation-All features are important for prediction .Let's go with these feature.

# %% [markdown]
# ## <span style="color:Purple">Split the data into training and testing sets

# %%
# Split the data into training and testing sets 
from sklearn.model_selection import train_test_split
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split (x_scaled, y, test_size = .30, random_state = i)


print("Total Size Of Feature in Dataset :",x_scaled.shape)
print("Total Size Of Training Feature Dataset : " ,x_train.shape)
print("Total Size Of Testing Feature Dataset : ", x_test.shape)

print("Total Size Of Label in Dataset :",y.shape)
print("Total Size Of Training Label Dataset : " ,y_train.shape)
print("Total Size Of Testing Label Dataset : ", y_test.shape)
# Out:
# Total Size Of Feature in Dataset : (5238, 9)
# Total Size Of Training Feature Dataset :  (3666, 9)
# Total Size Of Testing Feature Dataset :  (1572, 9)
# Total Size Of Label in Dataset : (5238,)
# Total Size Of Training Label Dataset :  (3666,)
# Total Size Of Testing Label Dataset :  (1572,)

# %% [markdown]
# # <span style="color:purple">Create one function and call as many as times to check score of different model and model Overfitting.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

def model_score(model_name,x_train,x_test,y_train,y_test, train=True):
    if train: #checking training score 
        y_pred_train=model_name.predict(x_train)
        
        print("\n*********************Train Result*********************")
        
        print("R2 Score on train data:",r2_score(y_train,y_pred_train))
        
    elif train==False: #checking testing score 
        y_pred_test=model_name.predict(x_test)
        
        print("\n*********************Test Result*********************")
        
        print("R2 Score on test data:",r2_score(y_test,y_pred_test))
        print("Mean Absolute Error :",mean_absolute_error(y_test,y_pred_test))
        print("Mean Squared Error :",mean_squared_error(y_test,y_pred_test))
        print("Root Mean Squared Error :",np.sqrt(mean_squared_error(y_test,y_pred_test))) 
        
        print("\n*********************Cross-Validation score*********************")
        print("Overall Cross-Validation score :",cross_val_score(model_name,x_scaled, y,cv=5).mean())
        
        print("\n************Difference in CV score and Accuracy score***********")
        deviation= ((r2_score(y_test,y_pred_test))-(cross_val_score(model_name,x_scaled, y,cv=5).mean()))
        print("Difference",deviation)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train, y_train)

#Call the function and pass datset to check train and test score 
model_score(LR,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(LR,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.3269419047817883
#
# *********************Test Result*********************
# R2 Score on test data: 0.2999821904951324
# Mean Absolute Error : 0.11866554055202733
# Mean Squared Error : 0.0229794804081319
# Root Mean Squared Error : 0.15158984269446255
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.1603962130057155
#
# ************Difference in CV score and Accuracy score***********
# Difference 0.13958597748941692

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
Decision_tree = DecisionTreeRegressor()
Decision_tree.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(Decision_tree,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(Decision_tree,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.997688783512074
#
# *********************Test Result*********************
# R2 Score on test data: 0.5040501996423619
# Mean Absolute Error : 0.09257541274487252
# Mean Squared Error : 0.01628054110337035
# Root Mean Squared Error : 0.1275952236698943
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.12675199920411043
#
# ************Difference in CV score and Accuracy score***********
# Difference 0.39630171027312566

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor()
RFR.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(RFR,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(RFR,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9621217460179673
#
# *********************Test Result*********************
# R2 Score on test data: 0.7106357140819197
# Mean Absolute Error : 0.0712214213043113
# Mean Squared Error : 0.009498959667570236
# Root Mean Squared Error : 0.09746260650921582
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.547848415664973
#
# ************Difference in CV score and Accuracy score***********
# Difference 0.16469593383151582

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost = AdaBoostRegressor()
adaboost.fit(x_train,y_train)
#Call the function and pass datset to check train and test score 
model_score(adaboost,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(adaboost,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.5509003081176664
#
# *********************Test Result*********************
# R2 Score on test data: 0.5176014449995933
# Mean Absolute Error : 0.09975499159493177
# Mean Squared Error : 0.0158356944538079
# Root Mean Squared Error : 0.12583995571283352
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.2977626649373545
#
# ************Difference in CV score and Accuracy score***********
# Difference 0.2379796033837836

# %% [markdown]
# # Support Vector Regression.

# %%
from sklearn.svm import SVR
svm=SVR()
svm.fit(x_train,y_train)
#Call the function and pass datset to check train and test score 
model_score(svm,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(svm,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.7063909488606702
#
# *********************Test Result*********************
# R2 Score on test data: 0.598581046566059
# Mean Absolute Error : 0.08901341686520198
# Mean Squared Error : 0.01317737756188318
# Root Mean Squared Error : 0.11479275918751661
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.46424355501022596
#
# ************Difference in CV score and Accuracy score***********
# Difference 0.13433749155583308

# %% [markdown]
# ## <span style="color:green">Conclusion- On basis of R2 score on (test & train) data and  CV score we can conclude that out of all model,
# ### <span style="color:purple">- R^2 Score of RandomForestRegressor = 70.94%
# ### <span style="color:green">perform best for this dataset . So we select this model for Hyperparameter Tunning.

# %% [markdown]
# ## <span style="color:purple">HyperParameter Tuning for RandomForestRegressor model

# %%
from sklearn.model_selection import  GridSearchCV
RFR.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_rfr = GridSearchCV(RandomForestRegressor(), param_grid=param_grid,cv= 5)
grid_rfr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
grid_rfr.best_params_
# Out:
# {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators= 200, min_samples_leaf=1,min_samples_split=2)
rfr.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(rfr,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(rfr,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9625334440893569
#
# *********************Test Result*********************
# R2 Score on test data: 0.7133657942838112
# Mean Absolute Error : 0.07066255004294832
# Mean Squared Error : 0.009409339341258302
# Root Mean Squared Error : 0.09700174916597279
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.5485758996028804
#
# ************Difference in CV score and Accuracy score***********
# Difference 0.17118347870503314

# %% [markdown]
# ## <span style="color:green">Conclusion- Here we see that after Hperparameter tunning model,
# ### <span style="color:purple">- R^2 Score of RandomForestRegressor = 71.34% (slightly increase from 70.94%)
# ### <span style="color:green">Hence i considered RandomForestRegressor as our final model for predicting Rental Price with least Mean Absolute Error. Let's go with this model

# %%
#saving Model
import joblib
joblib.dump(rfr,'Model to Predict Rental Price')
# Out:
# ['Model to Predict Rental Price']

# %%
#Model Prediction
rent = joblib.load('Model to Predict Rental Price')
Rent = rent.predict(x_test)

# %% [markdown]
# ## <span style="color:purple">Prediction Comparision

# %%
test_data = np.array(y_test)
Rent_Pred = pd.DataFrame({'predicted': Rent,'original':test_data})

# %%
Rent_Pred
# Out:
#           predicted  original
# 0      87140.451955   62340.0
# 1     109648.183786  105978.0
# 2     112464.941769  153772.0
# 3     119889.357898   83951.0
# 4      78801.990212   47378.0
# ...             ...       ...
# 1567   92848.819626  130332.0
# 1568   80804.096330   78881.0
# 1569   70081.488175   68574.0
# 1570  104459.066045   81042.0
# 1571  140265.615566  128836.0
#
# [1572 rows x 2 columns]

# %% [markdown]
# ## <span style="color:green"> As we can see, predicted and original values are almost close.

# %% [markdown]
# ##  <span style="color:red">Model 2- Predicting 'area(sq.ft)'

# %%
df_two.shape
# Out:
# (5238, 11)

# %%
df_two.head()
# Out:
#    amenities  bathrooms  bedrooms  pets_allowed  area(sq.ft)  address  \
# 0         27   -0.96645       0.0             0     4.657010     4143
# 1         27   -0.96645       1.0             0     4.732623     3827
# 2         27   -0.96645       0.0             0     4.747459     4143
# 3         27   -0.96645       0.0             0     4.876999     1134
# 4         27   -0.96645       0.0             0     5.000000     4143
#
#    cityname  state  latitude  longitude  price(in rupees)
# 0      1082      6   38.9057   -76.9861          3.429725
# 1       317     13   37.9680   -87.6621          3.201429
# 2        34     43   38.8910   -77.0816          3.651948
# 3       948     45   47.6160  -122.3275          3.490374
# 4        34     43   38.8738   -77.1055          3.471088

# %%
#Visualizing Correlaton using Bar Plot
plt.figure(figsize = (15,5))
df_two_corr = df_two.corr()
df_two_corr['area(sq.ft)'].sort_values(ascending=False).drop('area(sq.ft)').plot.bar()
plt.xticks(fontsize =15)
plt.xlabel('Features', fontsize =15)
plt.ylabel('Correlation_Value', fontsize =15)
plt.title('Correlaton using Bar Plot', fontsize =25)
plt.show()

# %% [markdown]
# <span style="color:BLUE">Observation -
# - Column 'latitude' & 'cityname' has  no correlated with 'area(sq.ft)'.
# Let's drop these value.

# %%
#Dropping  'latitude', 'cityname' column
df_two.drop(['latitude', 'cityname'],axis=1,inplace=True)
df_two.shape
# Out:
# (5238, 9)

# %% [markdown]
# ## <span style="color:purple">Seperating Feature and Label

# %%
#Seperating Feature and label into x1 and y1
x1=df_two.drop(["area(sq.ft)"],axis=1)
y1=df_two["area(sq.ft)"]

print("Feature Dimension :" ,x1.shape)
print("Target Dimension :" ,y1.shape)
# Out:
# Feature Dimension : (5238, 8)
# Target Dimension : (5238,)

# %% [markdown]
# ## <span style="color:purple">Feature Scaling Using Standard Scaler

# %%
# data scaling 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x1_scaled = pd.DataFrame(scaler.fit_transform(x1),columns=x1.columns)

# %% [markdown]
# ## <span style="color:purple">Detecting Multicollinearity Using a Variance Inflation Factor (VIF)

# %%
#finding VIF in each scaled column i.e x_scaled.shape[1](1/1- R^2 )
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame() 

vif["VIF"] = [variance_inflation_factor(x1_scaled.values, i) for i in range(len(x1_scaled.columns))]
vif["Features"] = x1_scaled.columns
vif
# Out:
#         VIF          Features
# 0  1.030230         amenities
# 1  1.821451         bathrooms
# 2  1.717791          bedrooms
# 3  1.047250      pets_allowed
# 4  1.044591           address
# 5  1.065398             state
# 6  1.118631         longitude
# 7  1.338896  price(in rupees)

# %% [markdown]
# <span style="color:blue">Observation - THe VIF value is below 10 in all feature ,Hence no multicollinearity observed.
# Lets go ahead with these feature.

# %% [markdown]
# ## <span style="color:purple"> Feature Selection by SelectKBest

# %%
from sklearn.feature_selection import SelectKBest, f_classif

best_fit = SelectKBest(score_func = f_classif, k =8)
fit = best_fit.fit(x1_scaled,y1)

#Craete DataFrame for score and column
df_scores = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(x1_scaled.columns)

#Concatenate the score and column
featureScores = pd.concat([df_columns,df_scores],axis = 1)
featureScores.columns = ['Feature', 'Score']

#print the top 8 feature based on score
print(featureScores.nlargest(8,'Score'))
# Out:
#             Feature     Score
# 1         bathrooms  8.869332
# 2          bedrooms  6.468711
# 7  price(in rupees)  1.901817
# 3      pets_allowed  1.312174
# 5             state  1.256171
# 4           address  1.215683
# 6         longitude  1.175964
# 0         amenities  1.072001

# %% [markdown]
# <span style="color:blue">Obsevation-All features are important for prediction .Let's go with these feature.

# %% [markdown]
# ## <span style="color:Purple">Split the data into training and testing sets

# %%
# Split the data into training and testing sets 
from sklearn.model_selection import train_test_split
for i in range(1,100):
    x1_train,x1_test,y1_train,y1_test = train_test_split (x1_scaled, y1, test_size = .30, random_state = i)


print("Total Size Of Feature in Dataset :",x1_scaled.shape)
print("Total Size Of Training Feature Dataset : " ,x1_train.shape)
print("Total Size Of Testing Feature Dataset : ", x1_test.shape)

print("Total Size Of Label in Dataset :",y1.shape)
print("Total Size Of Training Label Dataset : " ,y1_train.shape)
print("Total Size Of Testing Label Dataset : ", y1_test.shape)
# Out:
# Total Size Of Feature in Dataset : (5238, 8)
# Total Size Of Training Feature Dataset :  (3666, 8)
# Total Size Of Testing Feature Dataset :  (1572, 8)
# Total Size Of Label in Dataset : (5238,)
# Total Size Of Training Label Dataset :  (3666,)
# Total Size Of Testing Label Dataset :  (1572,)

# %% [markdown]
# # <span style="color:purple">Create one function and call as many as times to check score of different model and model Overfitting.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

def model_score(model_name,x1_train,x1_test,y1_train,y1_test, train=True):
    if train: #checking training score 
        y_pred_train=model_name.predict(x1_train)
        
        print("\n*********************Train Result*********************")
        
        print("R2 Score on train data:",r2_score(y1_train,y_pred_train))
        
    elif train==False: #checking testing score 
        y_pred_test=model_name.predict(x1_test)
        
        print("\n*********************Test Result*********************")
        
        print("R2 Score on test data:",r2_score(y1_test,y_pred_test))
        print("Mean Absolute Error :",mean_absolute_error(y1_test,y_pred_test))
        print("Mean Squared Error :",mean_squared_error(y1_test,y_pred_test))
        print("Root Mean Squared Error :",np.sqrt(mean_squared_error(y1_test,y_pred_test))) 
        
        print("\n*********************Cross-Validation score*********************")
        print("Overall Cross-Validation score :",cross_val_score(model_name,x1_scaled, y,cv=5).mean())
        
        print("\n************Difference in CV score and Accuracy score***********")
        deviation= ((r2_score(y1_test,y_pred_test))-(cross_val_score(model_name,x1_scaled, y,cv=5).mean()))
        print("Difference",deviation)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x1_train, y1_train)

#Call the function and pass datset to check train and test score 
model_score(LR,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(LR,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.6943821586021849
#
# *********************Test Result*********************
# R2 Score on test data: 0.695338255565296
# Mean Absolute Error : 0.6668898253561836
# Mean Squared Error : 0.7717281759890119
# Root Mean Squared Error : 0.8784806064956766
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 1.0
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.30466174443470395

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
Decision_tree = DecisionTreeRegressor()
Decision_tree.fit(x1_train, y1_train)
#Call the function and pass datset to check train and test score 
model_score(Decision_tree,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(Decision_tree,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9999603792461522
#
# *********************Test Result*********************
# R2 Score on test data: 0.555391380029284
# Mean Absolute Error : 0.7540061609569497
# Mean Squared Error : 1.1262227883439775
# Root Mean Squared Error : 1.061236443185013
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.9995628423892458
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.4443237673072946

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor()
RFR.fit(x1_train, y1_train)
#Call the function and pass datset to check train and test score 
model_score(RFR,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(RFR,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9673369325865854
#
# *********************Test Result*********************
# R2 Score on test data: 0.7774434160283021
# Mean Absolute Error : 0.5463667590015169
# Mean Squared Error : 0.5637504207215438
# Root Mean Squared Error : 0.7508331510539101
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.9996217262343358
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.22219416884644838

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost = AdaBoostRegressor()
adaboost.fit(x1_train,y1_train)
#Call the function and pass datset to check train and test score 
model_score(adaboost,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(adaboost,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.6674783608541863
#
# *********************Test Result*********************
# R2 Score on test data: 0.656041238859602
# Mean Absolute Error : 0.7353082072669845
# Mean Squared Error : 0.8712700960957379
# Root Mean Squared Error : 0.9334184999750851
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.9924382532323118
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.33751566245578557

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
from sklearn.svm import SVR
svm=SVR()
svm.fit(x1_train,y1_train)
#Call the function and pass datset to check train and test score 
model_score(svm,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(svm,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.7739681501461815
#
# *********************Test Result*********************
# R2 Score on test data: 0.7496518150428266
# Mean Absolute Error : 0.5831336701159949
# Mean Squared Error : 0.6341483683737212
# Root Mean Squared Error : 0.796334332032546
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.8984971437846948
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.14884532874186818

# %% [markdown]
# ## <span style="color:green">Conclusion- On basis of R2 score on (test & train) data and  CV score we can conclude that out of all model,
# ### <span style="color:purple">- R^2 Score of RandomForestRegressor = 77.59%
# ### <span style="color:purple">- R^2 Score of Support Vector Regression = 74.96%
# ### <span style="color:green">perform best for this dataset . So we select these model for Hyperparameter Tunning and then decide our final model among these two.

# %% [markdown]
# ## <span style="color:purple">HyperParameter Tuning for RandomForestRegressor model

# %%
from sklearn.model_selection import  GridSearchCV
RFR.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_rfr1 = GridSearchCV(RandomForestRegressor(), param_grid=param_grid,cv= 5)
grid_rfr1.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
grid_rfr1.best_params_
# Out:
# {'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50}

# %%
from sklearn.ensemble import RandomForestRegressor
rfr1=RandomForestRegressor(n_estimators= 50, min_samples_leaf=1,min_samples_split=10)
rfr1.fit(x1_train, y1_train)
#Call the function and pass datset to check train and test score 
model_score(rfr1,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(rfr1,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9161791267421451
#
# *********************Test Result*********************
# R2 Score on test data: 0.7806088895640316
# Mean Absolute Error : 0.5430540779961857
# Mean Squared Error : 0.5557320686885284
# Root Mean Squared Error : 0.7454743917053949
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.9994545453391865
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.21887085342747192

# %% [markdown]
# ## <span style="color:purple">HyperParameter Tuning for Support Vector Regression (SVR) model

# %%
svm.get_params().keys()
# Out:
# dict_keys(['C', 'cache_size', 'coef0', 'degree', 'epsilon', 'gamma', 'kernel', 'max_iter', 'shrinking', 'tol', 'verbose'])

# %%
param_grid = {
    'kernel': ['rbf'],
    'C': [0.1, 1],
    'epsilon': [0.1, 0.001],
}

# %%
grid_svm = GridSearchCV(SVR(), param_grid=param_grid,cv= 5)
grid_svm.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [0.1, 1], 'epsilon': [0.1, 0.001],
#                          'kernel': ['rbf']})

# %%
grid_svm.best_params_
# Out:
# {'C': 1, 'epsilon': 0.1, 'kernel': 'rbf'}

# %%
SVM= SVR( kernel = 'rbf',  C=1, epsilon=0.1)
SVM.fit(x1_train,y1_train)
#Call the function and pass datset to check train and test score 
model_score(SVM,x1_train,x1_test,y1_train,y1_test, train=True) #This is training score
model_score(SVM,x1_train,x1_test,y1_train,y1_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.7739681501461815
#
# *********************Test Result*********************
# R2 Score on test data: 0.7496518150428266
# Mean Absolute Error : 0.5831336701159949
# Mean Squared Error : 0.6341483683737212
# Root Mean Squared Error : 0.796334332032546
#
# *********************Cross-Validation score*********************
# Overall Cross-Validation score : 0.8984971437846948
#
# ************Difference in CV score and Accuracy score***********
# Difference -0.14884532874186818

# %% [markdown]
# ## <span style="color:green">Conclusion- Here we see that after Hperparameter tunning all three model,
# ### <span style="color:purple">- R^2 Score of RandomForestRegressor = 78.30% (slightly increase from 77.59%)
# ### <span style="color:purple">- R^2 Score of Support Vector Regression (SVR) = 74.96% (remain same)
# ### <span style="color:green">Hence i considered RandomForestRegressor as our final model with least Mean Absolute Error. Let's go with this model

# %%
#saving Model
import joblib
joblib.dump(rfr1,'Model to Predict Area in sq.ft')
# Out:
# ['Model to Predict Area in sq.ft']

# %%
#Model Prediction
area = joblib.load('Model to Predict Area in sq.ft')
Area = area.predict(x1_test)

# %% [markdown]
# ## <span style="color:purple">Prediction Comparision

# %%
test_data1 = np.array(y1_test)
Area_Pred = pd.DataFrame({'predicted': Area,'original':test_data1})

# %%
Area_Pred
# Out:
#         predicted  original
# 0      265.467303     250.0
# 1      564.038299     623.0
# 2     1593.488106    1356.0
# 3     1183.378261    1237.0
# 4      489.299079     707.0
# ...           ...       ...
# 1567  1172.463951     828.0
# 1568   650.611157     687.0
# 1569   703.073589     576.0
# 1570   728.116578    1324.0
# 1571  1389.360593    1650.0
#
# [1572 rows x 2 columns]

# %% [markdown]
# ## <span style="color:green"> As we can see, predicted and original values are almost close.
